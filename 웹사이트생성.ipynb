# %%
with open('clean_K.html','w',encoding='utf8') as f:
    f.write(
'''
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8">
    <title>클린케이 영등포점</title>
    <style>
      h1 {
        color: deeppink;
      }
      nav ul li a {
        color: blue;
      }
      section h1, section p {
        text-align: left;
      }
    </style>
    <script>
      window.onload = function() {
        var shoes = document.querySelector("#shoes");
        var bags = document.querySelector("#bags");
        var blanket = document.querySelector("#blanket");
        
        shoes.addEventListener("click", function() {
          var content = document.querySelector("#content1");
          content.style.display = "block";
        });
        
        bags.addEventListener("click", function() {
          var content = document.querySelector("#content2");
          content.style.display = "block";
        });
        
        blanket.addEventListener("click", function() {
          var content = document.querySelector("#content3");
          content.style.display = "block";
        });
      };
    </script>
  </head>
  <body>
  
    <header>
    <h1>클린케이 영등포점</h1>
    <p>업데이트 되는 정보들을 문자로 발송해드립니다.</p>
    <input type="text" name = "usernumber" placeholder="전화번호를 입력하세요.">
    <table>
        <tbody>
            <tr>
                <th>카톡 수신 동의</th>
            </tr>
            <tr>
                <td>  예  </td>
                <td>  □  </td>
            </tr>
            <tr>
                <td> 아니오 </td>
                <td>  □  </td>
            </tr>
        </tbody>
    </table>
      <nav>
        <ul>
          <li><a href="#" id="shoes">shoes</a></li>
          <li><a href="#" id="bags">bags</a></li>
          <li><a href="#" id="blanket">blanket</a></li>
        </ul>
      </nav>
    </header>
    <main>
      <section id="content1" style="display:none;">
        <h3>shoes</h3>
        <nav>
        <ul>
          <li><a href="#">일반운동화</a></li>
          <li><a href="#">명품운동화</a></li>
          <li><a href="#">가죽운동화</a></li>
        </ul>
      </nav>
      </section>
      <section id="content2" style="display:none;">
        <h3>bags</h3>
        <nav>
        <ul>
          <li><a href="#">일반가방</a></li>
          <li><a href="#">명품가방</a></li>
          <li><a href="#">가죽가방</a></li>
        </ul>
      </nav>
      </section>
      <section id="content3" style="display:none;">
        <h3>blanket</h3>
        <nav>
        <ul>
          <li><a href="#">일반이불</a></li>
          <li><a href="#">명품이불</a></li>
          <li><a href="#">솜이불</a></li>
        </ul>
      </nav>
      </section>
    </main>
    <img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221115_286%2F1668498478375qeTTS_JPEG%2F20221104_105310.jpg" 
    alt="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221115_286%2F1668498478375qeTTS_JPEG%2F20221104_105310.jpg"
    style="width: 20%; height: auto;">
    <footer>
      <p>저작권 © 2023 예시 회사. 모든 권리 보유.</p>
    </footer>
  </body>
</html>
''')
